# %%
import pandas as pd
import os
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import time

#sklearn libraries
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import normalize
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score,matthews_corrcoef,classification_report,roc_curve
from sklearn.externals import joblib
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn import preprocessing
from sklearn.svm import SVC
from sklearn.ensemble  import AdaBoostClassifier

import gc
from datetime import datetime 
from time import time
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
# Out:
# /Users/glenmond/opt/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %%
card = pd.read_csv('card.csv',index_col =0, header = 1)

# %%
card
# Out:
#        LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1          20000    2          2         1   24      2      2     -1     -1
# 2         120000    2          2         2   26     -1      2      0      0
# 3          90000    2          2         2   34      0      0      0      0
# 4          50000    2          2         1   37      0      0      0      0
# 5          50000    1          2         1   57     -1      0     -1      0
# ...          ...  ...        ...       ...  ...    ...    ...    ...    ...
# 29996     220000    1          3         1   39      0      0      0      0
# 29997     150000    1          3         2   43     -1     -1     -1     -1
# 29998      30000    1          2         2   37      4      3      2     -1
# 29999      80000    1          3         1   41      1     -1      0      0
# 30000      50000    1          2         1   46      0      0      0      0
#
#        PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  \
# ID            ...
# 1         -2  ...          0          0          0         0       689
# 2          0  ...       3272       3455       3261         0      1000
# 3          0  ...      14331      14948      15549      1518      1500
# 4          0  ...      28314      28959      29547      2000      2019
# 5          0  ...      20940      19146      19131      2000     36681
# ...      ...  ...        ...        ...        ...       ...       ...
# 29996      0  ...      88004      31237      15980      8500     20000
# 29997      0  ...       8979       5190          0      1837      3526
# 29998      0  ...      20878      20582      19357         0         0
# 29999      0  ...      52774      11855      48944     85900      3409
# 30000      0  ...      36535      32428      15313      2078      1800
#
#        PAY_AMT3  PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ID
# 1             0         0         0         0                           1
# 2          1000      1000         0      2000                           1
# 3          1000      1000      1000      5000                           0
# 4          1200      1100      1069      1000                           0
# 5         10000      9000       689       679                           0
# ...         ...       ...       ...       ...                         ...
# 29996      5003      3047      5000      1000                           0
# 29997      8998       129         0         0                           0
# 29998     22000      4200      2000      3100                           1
# 29999      1178      1926     52964      1804                           1
# 30000      1430      1000      1000      1000                           1
#
# [30000 rows x 24 columns]

# %%
card.head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# ID
# 1       20000    2          2         1   24      2      2     -1     -1
# 2      120000    2          2         2   26     -1      2      0      0
# 3       90000    2          2         2   34      0      0      0      0
# 4       50000    2          2         1   37      0      0      0      0
# 5       50000    1          2         1   57     -1      0     -1      0
#
#     PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ID         ...
# 1      -2  ...          0          0          0         0       689         0
# 2       0  ...       3272       3455       3261         0      1000      1000
# 3       0  ...      14331      14948      15549      1518      1500      1000
# 4       0  ...      28314      28959      29547      2000      2019      1200
# 5       0  ...      20940      19146      19131      2000     36681     10000
#
#     PAY_AMT4  PAY_AMT5  PAY_AMT6  default payment next month
# ID
# 1          0         0         0                           1
# 2       1000         0      2000                           1
# 3       1000      1000      5000                           0
# 4       1100      1069      1000                           0
# 5       9000       689       679                           0
#
# [5 rows x 24 columns]

# %%
card.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30000 entries, 1 to 30000
# Data columns (total 24 columns):
# LIMIT_BAL                     30000 non-null int64
# SEX                           30000 non-null int64
# EDUCATION                     30000 non-null int64
# MARRIAGE                      30000 non-null int64
# AGE                           30000 non-null int64
# PAY_0                         30000 non-null int64
# PAY_2                         30000 non-null int64
# PAY_3                         30000 non-null int64
# PAY_4                         30000 non-null int64
# PAY_5                         30000 non-null int64
# PAY_6                         30000 non-null int64
# BILL_AMT1                     30000 non-null int64
# BILL_AMT2                     30000 non-null int64
# BILL_AMT3                     30000 non-null int64
# BILL_AMT4                     30000 non-null int64
# BILL_AMT5                     30000 non-null int64
# BILL_AMT6                     30000 non-null int64
# PAY_AMT1                      30000 non-null int64
# PAY_AMT2                      30000 non-null int64
# PAY_AMT3                      30000 non-null int64
# PAY_AMT4                      30000 non-null int64
# PAY_AMT5                      30000 non-null int64
# PAY_AMT6                      30000 non-null int64
# default payment next month    30000 non-null int64
# dtypes: int64(24)
# memory usage: 5.7 MB

# %%
card.describe()
# Out:
#             LIMIT_BAL           SEX     EDUCATION      MARRIAGE           AGE  \
# count    30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean    167484.322667      1.603733      1.853133      1.551867     35.485500
# std     129747.661567      0.489129      0.790349      0.521970      9.217904
# min      10000.000000      1.000000      0.000000      0.000000     21.000000
# 25%      50000.000000      1.000000      1.000000      1.000000     28.000000
# 50%     140000.000000      2.000000      2.000000      2.000000     34.000000
# 75%     240000.000000      2.000000      2.000000      2.000000     41.000000
# max    1000000.000000      2.000000      6.000000      3.000000     79.000000
#
#               PAY_0         PAY_2         PAY_3         PAY_4         PAY_5  \
# count  30000.000000  30000.000000  30000.000000  30000.000000  30000.000000
# mean      -0.016700     -0.133767     -0.166200     -0.220667     -0.266200
# std        1.123802      1.197186      1.196868      1.169139      1.133187
# min       -2.000000     -2.000000     -2.000000     -2.000000     -2.000000
# 25%       -1.000000     -1.000000     -1.000000     -1.000000     -1.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        8.000000      8.000000      8.000000      8.000000      8.000000
#
#        ...      BILL_AMT4      BILL_AMT5      BILL_AMT6       PAY_AMT1  \
# count  ...   30000.000000   30000.000000   30000.000000   30000.000000
# mean   ...   43262.948967   40311.400967   38871.760400    5663.580500
# std    ...   64332.856134   60797.155770   59554.107537   16563.280354
# min    ... -170000.000000  -81334.000000 -339603.000000       0.000000
# 25%    ...    2326.750000    1763.000000    1256.000000    1000.000000
# 50%    ...   19052.000000   18104.500000   17071.000000    2100.000000
# 75%    ...   54506.000000   50190.500000   49198.250000    5006.000000
# max    ...  891586.000000  927171.000000  961664.000000  873552.000000
#
#            PAY_AMT2      PAY_AMT3       PAY_AMT4       PAY_AMT5  \
# count  3.000000e+04   30000.00000   30000.000000   30000.000000
# mean   5.921163e+03    5225.68150    4826.076867    4799.387633
# std    2.304087e+04   17606.96147   15666.159744   15278.305679
# min    0.000000e+00       0.00000       0.000000       0.000000
# 25%    8.330000e+02     390.00000     296.000000     252.500000
# 50%    2.009000e+03    1800.00000    1500.000000    1500.000000
# 75%    5.000000e+03    4505.00000    4013.250000    4031.500000
# max    1.684259e+06  896040.00000  621000.000000  426529.000000
#
#             PAY_AMT6  default payment next month
# count   30000.000000                30000.000000
# mean     5215.502567                    0.221200
# std     17777.465775                    0.415062
# min         0.000000                    0.000000
# 25%       117.750000                    0.000000
# 50%      1500.000000                    0.000000
# 75%      4000.000000                    0.000000
# max    528666.000000                    1.000000
#
# [8 rows x 24 columns]

# %%
card = card.rename(columns={'PAY_0': 'PAY_1','default payment next month': 'defPay'})

# %%
card.head()
# Out:
#     LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_1  PAY_2  PAY_3  PAY_4  \
# ID
# 1       20000    2          2         1   24      2      2     -1     -1
# 2      120000    2          2         2   26     -1      2      0      0
# 3       90000    2          2         2   34      0      0      0      0
# 4       50000    2          2         1   37      0      0      0      0
# 5       50000    1          2         1   57     -1      0     -1      0
#
#     PAY_5  ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ID         ...
# 1      -2  ...          0          0          0         0       689         0
# 2       0  ...       3272       3455       3261         0      1000      1000
# 3       0  ...      14331      14948      15549      1518      1500      1000
# 4       0  ...      28314      28959      29547      2000      2019      1200
# 5       0  ...      20940      19146      19131      2000     36681     10000
#
#     PAY_AMT4  PAY_AMT5  PAY_AMT6  defPay
# ID
# 1          0         0         0       1
# 2       1000         0      2000       1
# 3       1000      1000      5000       0
# 4       1100      1069      1000       0
# 5       9000       689       679       0
#
# [5 rows x 24 columns]

# %%
# Data Cleaning: for education
fil = (card.EDUCATION == 5) | (card.EDUCATION == 6) | (card.EDUCATION == 0)
card.loc[fil, 'EDUCATION'] = 4
card.EDUCATION.value_counts()
# Out:
# 2    14030
# 1    10585
# 3     4917
# 4      468
# Name: EDUCATION, dtype: int64

# %%
# Data Cleaning: for marriage
card.loc[card.MARRIAGE == 0, 'MARRIAGE'] = 3
card.MARRIAGE.value_counts()
# Out:
# 2    15964
# 1    13659
# 3      377
# Name: MARRIAGE, dtype: int64

# %%
# Data Cleaning: for PAY_1 to PAY_6
def histogram(data, variables, n_rows, n_cols, n_bins):
    fig=plt.figure()
    for i, var_name in enumerate(variables):
        ax=fig.add_subplot(n_rows,n_cols,i+1)
        data[var_name].hist(bins=n_bins,ax=ax)
        ax.set_title(var_name)
    fig.tight_layout()  # Improves appearance a bit.
    plt.show()

p = (card.PAY_1 == -2) | (card.PAY_1 == -1) | (card.PAY_1 == 0)
card.loc[p, 'PAY_1'] = 0
p = (card.PAY_2 == -2) | (card.PAY_2 == -1) | (card.PAY_2 == 0)
card.loc[p, 'PAY_2'] = 0
p = (card.PAY_3 == -2) | (card.PAY_3 == -1) | (card.PAY_3 == 0)
card.loc[p, 'PAY_3'] = 0
p = (card.PAY_4 == -2) | (card.PAY_4 == -1) | (card.PAY_4 == 0)
card.loc[p, 'PAY_4'] = 0
p = (card.PAY_5 == -2) | (card.PAY_5 == -1) | (card.PAY_5 == 0)
card.loc[p, 'PAY_5'] = 0
p = (card.PAY_6 == -2) | (card.PAY_6 == -1) | (card.PAY_6 == 0)
card.loc[p, 'PAY_6'] = 0
late = card[['PAY_1','PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6']]

# %%
# To check for missing data
card.isnull().any().sum()
# Out:
# 0

# %%
# to check correlation
plt.figure(figsize = (6,4))
sns.heatmap(card.corr(), cmap ='Blues', annot = False)

# %%
#Quality correlation matrix
k = 24 #number of varaibles for heatmap
cols = card.corr().nlargest(k, 'defPay')['defPay'].index
cm = card[cols].corr()
plt.figure(figsize=(10,6))
sns.heatmap(cm, annot=True, cmap = 'viridis')

# %%
#To check Outliers
l = card.columns.values
number_of_columns = 24
number_of_rows = len(l) -1/ number_of_columns
plt.figure(figsize=(number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.set_style('whitegrid')
    sns.boxplot(card[l[i]],color='green',orient='v')
    plt.tight_layout()

# %%
#To check distribution-Skewness
plt.figure(figsize=(2*number_of_columns,5*number_of_rows))
for i in range(0,len(l)):
    plt.subplot(number_of_rows + 1,number_of_columns,i+1)
    sns.distplot(card[l[i]],kde=True)

# %%
# heat map of correlation of features
correlation_matrix = card.corr()
fig = plt.figure(figsize=(12,9))
sns.heatmap(correlation_matrix,vmax=0.8,square = True)
plt.show()

# %%
# Split data into training and testing dataset
train_df, test_df = train_test_split(card, train_size = 0.7, test_size = 0.3, random_state=23)
target = 'defPay'
predictors = [  'LIMIT_BAL', 'SEX', 'EDUCATION', 'MARRIAGE', 'AGE', 
                'PAY_1', 'PAY_2', 'PAY_3', 'PAY_4', 'PAY_5', 'PAY_6', 
                'BILL_AMT1','BILL_AMT2', 'BILL_AMT3', 'BILL_AMT4', 'BILL_AMT5', 'BILL_AMT6',
                'PAY_AMT1', 'PAY_AMT2', 'PAY_AMT3', 'PAY_AMT4', 'PAY_AMT5', 'PAY_AMT6']

# %%
# Random Forest Classification

clf = RandomForestClassifier(n_jobs=None, 
                             n_estimators=100,
                             verbose=False)
clf.fit(train_df[predictors], train_df[target].values)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=False, warm_start=False)

# %%
preds = clf.predict(test_df[predictors])

# Feature Importance
tmp = pd.DataFrame({'Feature': predictors, 'Feature importance': clf.feature_importances_})
tmp = tmp.sort_values(by='Feature importance',ascending=False)
plt.figure(figsize = (7,4))
plt.title('Features importance',fontsize=14)
s = sns.barplot(x='Feature',y='Feature importance',data=tmp)
s.set_xticklabels(s.get_xticklabels(),rotation=90)
plt.show()

# %%
# Confusion matrix
cm = pd.crosstab(test_df[target].values, preds, rownames=['Actual'], colnames=['Predicted'])
fig, (ax1) = plt.subplots(ncols=1, figsize=(5,5))
sns.heatmap(cm, 
            xticklabels=['Not Default', 'Default'],
            yticklabels=['Not Default', 'Default'],
            annot=True,ax=ax1,
            linewidths=.2,linecolor="Darkblue", cmap="Blues")
plt.title('Confusion Matrix', fontsize=14)
plt.show()

# %%
#ROC-AUC score
roc_auc_score(test_df[target].values, preds)
# Out:
# 0.6516590989175212

# %%
# splitting the data again
X = card.drop(['defPay'],axis=1)
y = card['defPay']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 23)

# feature scaling thru standardisation
min_train = X_train.min()
range_train = (X_train - min_train).max()
X_train_scaled = (X_train - min_train)/range_train

min_test = X_test.min()
range_test = (X_test - min_test).max()
X_test_scaled = (X_test - min_test)/range_test
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-30f227f4e7dd> in <module>
#       4
#       5 # splitting the data again
# ----> 6 X = card2.drop(['defPay'],axis=1)
#       7 y = card2['defPay']
#       8 X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 23)
#
# AttributeError: 'StratifiedKFold' object has no attribute 'drop'

# %%
# Adaboost Classifier
adaboost =AdaBoostClassifier()

start = time()
adaboost.fit(X_train_scaled, y_train)
end = time()
train_time_ada=end-start

y_pred = adaboost.predict(X_test_scaled)
from sklearn.metrics import  accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
roc=roc_auc_score(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

results = pd.DataFrame([['Adaboost', acc,prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results
# Out:
#       Model  Accuracy  Precision    Recall  F1 Score       ROC
# 0  Adaboost  0.814556   0.683544  0.298793  0.415821  0.629787

# %%
# Gradient Boosting Classifier
from sklearn  import ensemble
gboost =ensemble.GradientBoostingClassifier()
start = time()
gboost.fit(X_train_scaled, y_train)
end=time()
train_time_g=end-start

y_pred = gboost.predict(X_test_scaled)
from sklearn.metrics import  accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
roc=roc_auc_score(y_test, y_pred)
acc = accuracy_score(y_test, y_pred)
prec = precision_score(y_test, y_pred)
rec = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

model_results = pd.DataFrame([['Gboost', acc,prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results = results.append(model_results,sort=False)
results
# Out:
#       Model  Accuracy  Precision    Recall  F1 Score       ROC
# 0  Adaboost  0.814556   0.683544  0.298793  0.415821  0.629787
# 0    Gboost  0.819333   0.665751  0.365694  0.472078  0.656820

# %%
# Random Forest
classifier = RandomForestClassifier(random_state = 47, 
                                    criterion = 'entropy',n_estimators=100)
start = time()
classifier.fit(X_train_scaled, y_train)
end=time()
train_time_r100=end-start

y_pred_r = classifier.predict(X_test_scaled)
from sklearn.metrics import  accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
roc=roc_auc_score(y_test, y_pred_r)
acc = accuracy_score(y_test, y_pred_r)
prec = precision_score(y_test, y_pred_r)
rec = recall_score(y_test, y_pred_r)
f1 = f1_score(y_test, y_pred_r)

model_results = pd.DataFrame([['Random_forest_ent100 ', acc,prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results = results.append(model_results, ignore_index = True, sort = False)
results
# Out:
#                    Model  Accuracy  Precision    Recall  F1 Score       ROC
# 0               Adaboost  0.814556   0.683544  0.298793  0.415821  0.629787
# 1                 Gboost  0.819333   0.665751  0.365694  0.472078  0.656820
# 2  Random_forest_ent100   0.812556   0.685117  0.280181  0.397715  0.621836

# %%
# SVC-SVM
from sklearn.svm import SVC 

svc_model = SVC(kernel='rbf', gamma=0.1,C=100)

start = time()
svc_model.fit(X_train_scaled, y_train)
end=time()
train_time_svc=end-start

from sklearn.metrics import classification_report, confusion_matrix
y_pred_svc = svc_model.predict(X_test_scaled)
from sklearn.metrics import  accuracy_score, f1_score, precision_score, recall_score, roc_auc_score
roc=roc_auc_score(y_test, y_pred_svc)
acc = accuracy_score(y_test, y_pred_svc)
prec = precision_score(y_test, y_pred_svc)
rec = recall_score(y_test, y_pred_svc)
f1 = f1_score(y_test, y_pred_svc)

model_results = pd.DataFrame([['SVC ', acc,prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results = results.append(model_results, ignore_index = True, sort = False)
results
# Out:
#                    Model  Accuracy  Precision    Recall  F1 Score       ROC
# 0               Adaboost  0.814556   0.683544  0.298793  0.415821  0.629787
# 1                 Gboost  0.819333   0.665751  0.365694  0.472078  0.656820
# 2  Random_forest_ent100   0.812556   0.685117  0.280181  0.397715  0.621836
# 3                   SVC   0.821778   0.711454  0.324950  0.446133  0.643793

# %%
# Naive Bayes
from sklearn.naive_bayes import GaussianNB
nb = GaussianNB()

start = time()
nb.fit(X_train_scaled, y_train)
end=time()
train_time_nb=end-start

y_pred_g = nb.predict(X_test_scaled)
roc=roc_auc_score(y_test, y_pred_g)
acc = accuracy_score(y_test, y_pred_g)
prec = precision_score(y_test, y_pred_g)
rec = recall_score(y_test, y_pred_g)
f1 = f1_score(y_test, y_pred_g)

model_results = pd.DataFrame([['Naive Bayes', acc,prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results = results.append(model_results, ignore_index = True, sort = False)
results
# Out:
#                    Model  Accuracy  Precision    Recall  F1 Score       ROC
# 0               Adaboost  0.814556   0.683544  0.298793  0.415821  0.629787
# 1                 Gboost  0.819333   0.665751  0.365694  0.472078  0.656820
# 2  Random_forest_ent100   0.812556   0.685117  0.280181  0.397715  0.621836
# 3                   SVC   0.821778   0.711454  0.324950  0.446133  0.643793
# 4            Naive Bayes  0.776889   0.495261  0.525654  0.510005  0.686886

# %%
from sklearn.linear_model import LogisticRegression
log = LogisticRegression(random_state=42)
start = time()
log.fit(X_train_scaled, y_train)
end=time()
train_time_log=end-start

y_pred_g = log.predict(X_test_scaled)
roc=roc_auc_score(y_test, y_pred_g)
acc = accuracy_score(y_test, y_pred_g)
prec = precision_score(y_test, y_pred_g)
rec = recall_score(y_test, y_pred_g)
f1 = f1_score(y_test, y_pred_g)

model_results = pd.DataFrame([['Log', acc,prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results = results.append(model_results, ignore_index = True, sort = False)
results
# Out:
# /Users/glenmond/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
#                    Model  Accuracy  Precision    Recall  F1 Score       ROC
# 0               Adaboost  0.814556   0.683544  0.298793  0.415821  0.629787
# 1                 Gboost  0.819333   0.665751  0.365694  0.472078  0.656820
# 2  Random_forest_ent100   0.812556   0.685117  0.280181  0.397715  0.621836
# 3                   SVC   0.821778   0.711454  0.324950  0.446133  0.643793
# 4            Naive Bayes  0.776889   0.495261  0.525654  0.510005  0.686886
# 5                    Log  0.816889   0.694508  0.305332  0.424179  0.633627

# %%
# KNN-classifier
knn = KNeighborsClassifier(n_neighbors = 7)

start = time()
knn.fit(X_train_scaled, y_train)
end=time()
train_time_knn=end-start

y_pred_g = knn.predict(X_test_scaled)
roc=roc_auc_score(y_test, y_pred_g)
acc = accuracy_score(y_test, y_pred_g)
prec = precision_score(y_test, y_pred_g)
rec = recall_score(y_test, y_pred_g)
f1 = f1_score(y_test, y_pred_g)

model_results = pd.DataFrame([['KNN 7', acc,prec,rec, f1,roc]],
               columns = ['Model', 'Accuracy', 'Precision', 'Recall', 'F1 Score','ROC'])
results = results.append(model_results, ignore_index = True, sort = False)
results
# Out:
#                    Model  Accuracy  Precision    Recall  F1 Score       ROC
# 0               Adaboost  0.814556   0.683544  0.298793  0.415821  0.629787
# 1                 Gboost  0.819333   0.665751  0.365694  0.472078  0.656820
# 2  Random_forest_ent100   0.812556   0.685117  0.280181  0.397715  0.621836
# 3                   SVC   0.821778   0.711454  0.324950  0.446133  0.643793
# 4            Naive Bayes  0.776889   0.495261  0.525654  0.510005  0.686886
# 5                    Log  0.816889   0.694508  0.305332  0.424179  0.633627
# 6                  KNN 7  0.805111   0.617000  0.310362  0.412985  0.627871

# %%
# Model Evaluation
model = ['Adaboost','SVC', 'GBOOST', 'Random forest', 'KNN7']
Train_Time = [
    train_time_ada,
    train_time_svc,
    train_time_g,
    train_time_r100,
    train_time_knn
]
index = np.arange(len(model))
plt.bar(index, Train_Time)
plt.xlabel('Machine Learning Models', fontsize=15)
plt.ylabel('Training Time', fontsize=15)
plt.xticks(index, model, fontsize=8, )
plt.title('Comparison of Training Time of all ML models')
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
# TODO: Initialize the three models
clf_A = GaussianNB()
clf_B = LogisticRegression(random_state=42)
clf_C = SVC(random_state=42)

# TODO: Execute the 'train_predict' function for each classifier and each training set size
# train_predict(clf, X_train, y_train, X_test, y_test)

for clf in [clf_A, clf_B, clf_C]:
    print (clf.class.name)
    train_predict(clf, X_train, y_train, X_test, y_test)
# Out:
#   File "<ipython-input-32-f69e231fb40b>", line 13
#     print (clf.class.name)
#                    ^
# SyntaxError: invalid syntax

# %%
# using Stratified K-Fold as sampling testing
from sklearn.model_selection import StratifiedKFold
StratifiedKFold(n_splits=2, random_state=23, shuffle=False)

# %%
#for poor
from sklearn.model_selection import StratifiedKFold
seed = 7

models2 = []
models2.append(('LR', LogisticRegression()))
#models2.append(('LDA', LinearDiscriminantAnalysis()))
models2.append(('KNN', KNeighborsClassifier()))
#models2.append(('CART', DecisionTreeClassifier()))
models2.append(('NB', GaussianNB()))
#models2.append(('LinearSVC', LinearSVC(random_state = 0)))
models2.append(('SVM - rbf', SVC()))
models2.append(('SVM - poly degree 8', SVC(kernel = 'poly', degree=12)))
#models2.append(('SVM - poly degree 3', SVC(kernel = 'poly', degree=3)))
#models2.append(('SVM - poly degree 2', SVC(kernel = 'poly', degree=2)))

#models2.append(('SVM', SVC()))
from sklearn import model_selection

results2 = []
names2 = []
scoring2 = 'accuracy'
for name, model in models2:
    kfold = StratifiedKFold(n_splits=2)
    cv_results = model_selection.cross_val_score(model, X_train_scaled, y_train, cv=kfold, scoring=scoring2)
    results2.append(cv_results)
    names2.append(name)
    msg2 = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg2)
# Out:
# /Users/glenmond/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# /Users/glenmond/opt/anaconda3/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LR: 0.814095 (0.001238)
# KNN: 0.788095 (0.000190)
# NB: 0.770000 (0.005143)
# /Users/glenmond/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/glenmond/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVM - rbf: 0.811048 (0.002190)
# /Users/glenmond/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /Users/glenmond/opt/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# SVM - poly degree 8: 0.778667 (0.000000)
